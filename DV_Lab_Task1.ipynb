# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpanjali316/Pandas_For_DataScience/blob/main/DV_Lab_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
import pandas as pd

# Upload file
uploaded = files.upload()

# Read the uploaded CSV
df = pd.read_csv(next(iter(uploaded)))
df.head()
# Out:
#      <input type="file" id="files-ffdfab2d-975d-4e61-8634-b64c7bda7258" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ffdfab2d-975d-4e61-8634-b64c7bda7258">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 2.	to get the data types of the given csv data (supermarket_sales.) fields

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# 5.	insert a column in the third position of the said excel sheet and fill it with NaN values

# %%
df.insert(3,"New_Column",np.nan)
df.head()
# Out:
#     Invoice ID Branch       City  New_Column Customer type  Gender  \
# 0  750-67-8428      A     Yangon         NaN        Member  Female
# 1  226-31-3081      C  Naypyitaw         NaN        Normal  Female
# 2  631-41-3108      A     Yangon         NaN        Normal    Male
# 3  123-19-1176      A     Yangon         NaN        Member    Male
# 4  373-73-7910      A     Yangon         NaN        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# ...

# %%
#columns
df.shape[0]
# Out:
# 1000

# %%
#rows
df.shape[1]
# Out:
# 18

# %% [markdown]
# 8.	Use duplicated() function to print the logical vector indicating the duplicate values present in the dataset supermarket_sales.

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# 9.	dataframe into groups based on city

# %%
df.groupby(by='City')

# %% [markdown]
# df.groupby('City') → Creates a GroupBy object where rows are grouped by each unique city.
#
# grouped is not a DataFrame, but an object you can iterate over or apply aggregations to.

# %%
grouped=df.groupby('City')
grouped.groups
# Out:
# {'Mandalay': [9, 10, 11, 15, 19, 21, 22, 26, 28, 30, 31, 32, 39, 40, 42, 45, 46, 47, 48, 52, 54, 62, 64, 67, 72, 81, 89, 93, 96, 99, 104, 110, 112, 116, 117, 119, 122, 124, 129, 130, 132, 133, 138, 148, 150, 156, 157, 158, 159, 164, 165, 171, 173, 174, 185, 186, 187, 190, 191, 193, 201, 203, 204, 208, 209, 212, 213, 214, 216, 218, 219, 220, 221, 226, 228, 230, 231, 232, 233, 238, 244, 246, 249, 250, 255, 262, 264, 267, 270, 274, 275, 285, 288, 290, 294, 301, 304, 310, 325, 328, ...], 'Naypyitaw': [1, 5, 7, 20, 34, 35, 38, 41, 43, 44, 49, 50, 53, 55, 59, 60, 61, 66, 70, 71, 73, 75, 76, 78, 79, 80, 82, 83, 84, 85, 86, 90, 91, 94, 97, 100, 101, 102, 106, 108, 109, 111, 114, 115, 121, 123, 127, 128, 134, 135, 140, 141, 142, 143, 145, 147, 151, 153, 154, 160, 163, 166, 172, 177, 179, 180, 181, 183, 189, 192, 195, 196, 198, 199, 200, 202, 206, 207, 211, 222, 223, 225, 227, 236, 237, 242, 251, 252, 259, 261, 266, 271, 276, 277, 278, 281, 286, 287, 291, 295, ...], 'Yangon': [0, 2, 3, 4, 6, 8
# ...

# %% [markdown]
# 10.	skipping first twenty rows into a Pandas dataframe.

# %% [markdown]
# this keeps all rows starting from index 20 onwards.
#
# The first 20 rows are effectively skipped/removed.

# %%
df=df.iloc[20:]

# %%
df
# Out:
#       Invoice ID Branch       City  New_Column Customer type  Gender  \
# 20   300-71-4605      C  Naypyitaw         NaN        Member    Male
# 21   371-85-5789      B   Mandalay         NaN        Normal    Male
# 22   273-16-6619      B   Mandalay         NaN        Normal    Male
# 23   636-48-8204      A     Yangon         NaN        Normal    Male
# 24   549-59-1358      A     Yangon         NaN        Member    Male
# ..           ...    ...        ...         ...           ...     ...
# 995  233-67-5758      C  Naypyitaw         NaN        Normal    Male
# 996  303-96-2227      B   Mandalay         NaN        Normal  Female
# 997  727-02-1313      A     Yangon         NaN        Member    Male
# 998  347-56-2442      A     Yangon         NaN        Normal    Male
# 999  849-09-3807      A     Yangon         NaN        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# ...

# %%
#to reset index
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#     Invoice ID Branch       City  New_Column Customer type Gender  \
# 0  300-71-4605      C  Naypyitaw         NaN        Member   Male
# 1  371-85-5789      B   Mandalay         NaN        Normal   Male
# 2  273-16-6619      B   Mandalay         NaN        Normal   Male
# 3  636-48-8204      A     Yangon         NaN        Normal   Male
# 4  549-59-1358      A     Yangon         NaN        Member   Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0  Electronic accessories       86.04         5  21.5100  451.7100  2/25/2019
# 1       Health and beauty       87.98         3  13.1970  277.1370   3/5/2019
# 2      Home and lifestyle       33.20         2   3.3200   69.7200  3/15/2019
# 3  Electronic accessories       34.56         5   8.6400  181.4400  2/17/2019
# 4       Sports and travel       88.63         3  13.2945  279.1845   3/2/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# ...

# %% [markdown]
# 11.	a dataframe and find details where ‘gross income ' > 39.824

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'New_Column', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['gross income']
# Out:
# 0      21.5100
# 1      13.1970
# 2       3.3200
# 3       8.6400
# 4      13.2945
#         ...
# 975     2.0175
# 976    48.6900
# 977     1.5920
# 978     3.2910
# 979    30.9190
# Name: gross income, Length: 980, dtype: float64

# %%
df[df['gross income']>39.824].head()
#this conditional selection gives an another data frame
# Out:
#      Invoice ID Branch       City  New_Column Customer type  Gender  \
# 29  574-22-5561      C  Naypyitaw         NaN        Member  Female
# 50  393-65-2792      C  Naypyitaw         NaN        Normal    Male
# 76  766-85-7061      B   Mandalay         NaN        Normal    Male
# 85  704-48-3927      A     Yangon         NaN        Member    Male
# 89  861-77-0145      C  Naypyitaw         NaN        Member    Male
#
#               Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 29     Fashion accessories       82.63        10  41.315  867.615  3/19/2019
# 50      Food and beverages       89.48        10  44.740  939.540   1/6/2019
# 76       Health and beauty       87.87        10  43.935  922.635  3/29/2019
# 85  Electronic accessories       88.67        10  44.335  931.035  1/12/2019
# 89  Electronic accessories       81.97        10  40.985  860.685   3/3/2019
#
#      Time      Payment   cogs  gross margin percentage  gross income  Rating
# ...

# %% [markdown]
# 12.	Pandas dataframe and display the last ten rows

# %%
df.tail(10)
# Out:
#       Invoice ID Branch       City  New_Column Customer type  Gender  \
# 970  886-18-2897      A     Yangon         NaN        Normal  Female
# 971  602-16-6955      B   Mandalay         NaN        Normal  Female
# 972  745-74-0715      A     Yangon         NaN        Normal    Male
# 973  690-01-6631      B   Mandalay         NaN        Normal    Male
# 974  652-49-6720      C  Naypyitaw         NaN        Member  Female
# 975  233-67-5758      C  Naypyitaw         NaN        Normal    Male
# 976  303-96-2227      B   Mandalay         NaN        Normal  Female
# 977  727-02-1313      A     Yangon         NaN        Member    Male
# 978  347-56-2442      A     Yangon         NaN        Normal    Male
# 979  849-09-3807      A     Yangon         NaN        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 970      Food and beverages       56.56         5  14.1400   296.9400
# ...

# %%
df['City']
# Out:
# 0      Naypyitaw
# 1       Mandalay
# 2       Mandalay
# 3         Yangon
# 4         Yangon
#          ...
# 975    Naypyitaw
# 976     Mandalay
# 977       Yangon
# 978       Yangon
# 979       Yangon
# Name: City, Length: 980, dtype: object

# %% [markdown]
# 13.	csv data (supermarket_sales) into a dataframe and find a specific city.

# %%
city_name=input("Enter city name to find : ")
city_name in df['City']
# Out:
# Enter city name to find : Yangon
# False

# %%
df[df['City']==city_name].head()
# Out:
#     Invoice ID Branch    City  New_Column Customer type  Gender  \
# 3  636-48-8204      A  Yangon         NaN        Normal    Male
# 4  549-59-1358      A  Yangon         NaN        Member    Male
# 5  227-03-5010      A  Yangon         NaN        Member  Female
# 7  189-17-4241      A  Yangon         NaN        Normal  Female
# 9  848-62-7243      A  Yangon         NaN        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 3  Electronic accessories       34.56         5   8.6400  181.4400  2/17/2019
# 4       Sports and travel       88.63         3  13.2945  279.1845   3/2/2019
# 5      Home and lifestyle       52.59         8  21.0360  441.7560  3/22/2019
# 7     Fashion accessories       87.67         2   8.7670  184.1070  3/10/2019
# 9       Health and beauty       24.89         9  11.2005  235.2105  3/15/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# ...

# %% [markdown]
# Filter for one city	df[df['City'] == 'Yangon']
# Filter for multiple cities	df[df['City'].isin(['Yangon', 'Mandalay'])]
# Case-insensitive filtering	df[df['City'].str.lower() == 'yangon']

# %%
#to check if a city name is present City column in given data frame
if "Yangon" in df['City'].values:
    print("Present")
else:
    print("Not present")
# Out:
# Present

# %% [markdown]
# 14.	Extract duplicate elements from the dataset supermarket_sales.

# %%
duplicate_rows=df[df.duplicated()] #returns a tuple
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, New_Column, Customer type, Gender, Product line, Unit price, Quantity, Tax 5%, Total, Date, Time, Payment, cogs, gross margin percentage, gross income, Rating]
# Index: []

# %% [markdown]
# How .duplicated() Works?
# Returns True for rows that are duplicates of earlier rows.
# Keeps the first occurrence as False and marks the rest as True.

# %%
#Count Total Number of Duplicate Rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 15.	to create a subtotal of " gross income" against city from the given csv data.

# %%
#Group by City and Calculate Subtotal
#The "Total" column usually represents the bill amount for each transaction.
df.groupby('City')['gross income'].sum()
# Out:
# City
# Mandalay     5008.6620
# Naypyitaw    5194.6900
# Yangon       4813.8975
# Name: gross income, dtype: float64

# %% [markdown]
# 16.	Extract unique elements from the dataset supermarket_sales.

# %%
#to get unique values for each column
df['City'].unique()
# Out:
# array(['Naypyitaw', 'Mandalay', 'Yangon'], dtype=object)

# %% [markdown]
# #to get unique values for each column
# for column in df.columns:
#     print(f"{column}: {df[column].unique()}")

# %% [markdown]
# 17.	How many unique elements are in the dataset supermarket_sales

# %%
# to count the no.of unique values for each column
for column in df.columns:
    print(f"{column}: {df[column].nunique()}")
# Out:
# Invoice ID: 980
# Branch: 3
# City: 3
# New_Column: 0
# Customer type: 2
# Gender: 2
# Product line: 6
# Unit price: 924
# Quantity: 10
# Tax 5%: 970
# Total: 970
# Date: 89
# Time: 500
# Payment: 3
# cogs: 970
# gross margin percentage: 1
# gross income: 970
# Rating: 61

# %% [markdown]
# 18.In a Pandas dataframe and to sort the records by the 'Date' column.

# %%
df.sort_values(by='Date',inplace=True)
df
# Out:
# /tmp/ipython-input-8008192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by='Date',inplace=True)
#       Invoice ID Branch       City  New_Column Customer type  Gender  \
# 809  416-17-9926      A     Yangon         NaN        Member  Female
# 464  493-65-6248      C  Naypyitaw         NaN        Member  Female
# 476  556-97-7101      C  Naypyitaw         NaN        Normal  Female
# 819  271-77-8740      C  Naypyitaw         NaN        Member  Female
# 225  530-90-9855      A     Yangon         NaN        Member    Male
# ..           ...    ...        ...         ...           ...     ...
# 413  616-87-0016      B   Mandalay         NaN        Normal    Male
# 104  268-27-6179      B   Mandalay         NaN        Member  Female
# ...
